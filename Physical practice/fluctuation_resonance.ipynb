# %%
import numpy as np
import matplotlib.pyplot as plt
I = [0, 10, 20, 60, 100, 180, 240, 320, 400, 500]
U = [0.4, 0.46, 0.5, 0.55, 0.6, 0.65, 0.7, 0.75, 0.8, 0.85]
plt.plot(I, U)

# %%
U2 = [0.1, 0.2, 0.31, 0.4, 0.51, 0.6, 0.7, 0.81, 0.9, 1.0]
f_rez = [817.5, 841, 847.3, 863.4, 872.8, 883.2, 985.5, 906.7, 912.1, 925.9]

# %%
U3_1 = [20, 24, 28, 40, 53, 100, 158, 320, 500, 960, 940, 921.6, 913, 880, 810, 730, 620, 536, 464, 368, 336, 250, 208]
f_gen_3_1 = [500, 550, 600, 650, 701.7, 800, 850, 900, 915, 920, 926, 950, 950, 940, 950, 960, 971, 980, 990, 1000, 1010, 1040, 1070]

# %%
U3_2 = [20, 22, 50, 72, 104, 416, 512, 960, 1180, 1360, 1620, 1900, 2140, 2340, 2520, 2880, 3060, 3080, 2880, 720, 600, 470, 390, 340, 300]
f_gen_3_2 = [500 ,600 , 700, 800, 850, 886, 900, 940, 950, 960, 970, 981, 990, 995, 1000, 1010, 1019, 1020, 1024, 1036, 1051, 1071, 1093, 1135]

# %%
U4_1 = [650, 610, 560, 470, 360,320, 160, 20, 96, 336, 384, 480, 560, 600, 660, 700, 40]
f_gen_4_1 = [1.867, 1.883, 1.894, 1.920, 1.949, 1.964, 1.978, 1.990, 1.979, 1.956, 1.941, 1.920, 1.900, 1.880, 1.862, 1.833, 1.809]

# %%
U4_2 = [64, 144, 380, 600, 880, 1040, 1080, 1160, 1200, 1400, 1560, 1920, 560, 40, 1060, 1300, 1420, 1400]
f_gen_4_2 = [1.900, 1.926, 1.941, 1.956, 1.983, 2.000, 2.015, 2.032, 2.047, 2.058, 2.080, 2.107, 2.115, 2.149, 2.109, 2.092, 2.072, 2.057]
